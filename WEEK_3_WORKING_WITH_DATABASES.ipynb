# %% [markdown]
# <a href="https://colab.research.google.com/github/Vissamsetty-Bharath/COMP-593/blob/main/WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?,?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
# myConnection.commit()
# myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-02-20 06:38:35.536376',
#   '2022-02-20 06:38:35.536387',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-13.0.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 4.5 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-13.0.0

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {} '.format( fake.name(), fake.job() ) )
# Out:
# Rebecca Love || Civil Service administrator
# Amanda Yates || Administrator, local government
# Robert Harper || Osteopath
# Cindy Brown || Public house manager
# Victoria Rivera || Manufacturing engineer
# David Watts || Radiographer, diagnostic
# Christopher Gutierrez || Training and development officer
# Emily Kelly || Company secretary
# Jeffery Sharp || Community arts worker
# Joel Parks || Chartered loss adjuster

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?,?);"""

fake = Faker()

#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!

for i in range(1000):
  myPerson = (fake.name(), 
            fake.email(), 
            fake.street_address(), 
            fake.city(), 
            fake.state(), 
            fake.country(), 
            fake.phone_number(), 
            fake.text(max_nb_chars=80),
            fake.date_of_birth(),
            fake.random_int(min=999,max=2500),
            datetime.now(), 
            datetime.now(),
            fake.ipv4())
  myCursor.execute(addPersonQuery, myPerson)
#myCursor.execute("SELECT * FROM people")
#pprint(myCursor.fetchall())
myConnection.commit()
myConnection.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#   '001-199-022-7319x3664',
#   'City couple we occur not population. Interest sure raise another green '
#   'writer.',
#   '2006-08-07',
#   1386,
#   '2022-02-20 07:14:57.605967',
#   '2022-02-20 07:14:57.605968',
#   '164.83.253.131'),
#  (648,
#   'Rebecca Williams',
#   'perezkimberly@example.net',
#   '514 Charles Loaf',
#   'North David',
#   'Wisconsin',
#   'Kenya',
#   '(370)075-2877',
#   'Anything federal create say. Catch development west place. Loss new '
#   'discuss.',
#   '2000-08-09',
#   1506,
#   '2022-02-20 07:14:57.606713',
#   '2022-02-20 07:14:57.606715',
#   '17.103.69.143'),
#  (649,
#   'James Jones',
#   'pcolon@example.net',
#   '4234 Gray Shores Apt. 813',
#   'North Zacharytown',
#   'Maine',
#   'Cayman Islands',
#   '156.935.2050x683',
#   'Treatment Mr seem find shake race support. Trouble already yeah serve long.',
#   '1988-04-22',
#   1103,
#   '2022-02-20 07:14:57.607473',
#   '2022-02-20 07:14:57.607474',
#   '18.229.63.68'),
#  (650,
#   'Benjamin Chang',
#   'gilbertannette@example.com',
#   '5767 Benton Row',
#   'Christensenchester',
#   'Louisiana',
#   'Niger',
#   '+1-942-538-3459x777',
#   'Soon deal watch tax central less.',
#   '1970-05-30',
#   1706,
#   '2022-02-20 07:14:57.608268',
#   '2022-02-20 07:14:57.608269',
#   '62.54.136.255'),
#  (651,
#   'Jermaine Hernandez',
#   'dmartin@example.com',
#   '028 Jonathan Inlet',
#   'East Stephanieville',
#   'Washington',
#   'Turkmenistan',
#   '(535)450-3663x27762',
#   'Mind unit nor friend around actually people.',
#   '1962-06-29',
#   2434,
#   '2022-02-20 07:14:57.608943',
#   '2022-02-20 07:14:57.608945',
#   '92.6.169.209'),
#  (652,
#   'Amy Martinez',
#   'hilljohn@example.net',
#   '43882 Kevin Ways Apt. 950',
#   'West Kristen',
#   'Utah',
#   'Marshall Islands',
#   '+1-995-115-4762x2262',
#   'Bring agree official area go lose. Beautiful benefit example off own.',
#   '1916-07-28',
#   1121,
#   '2022-02-20 07:14:57.609711',
#   '2022-02-20 07:14:57.609712',
#   '191.71.230.39'),
#  (653,
#   'James Flores',
#   'crawfordbrandy@example.net',
#   '106 Jason Fork',
#   'North Christopher',
#   'New Hampshire',
#   'Saudi Arabia',
#   '(404)284-6243x79081',
#   'She far baby say score. Close still leader medical.',
#   '1953-11-17',
#   1830,
#   '2022-02-20 07:14:57.610450',
#   '2022-02-20 07:14:57.610451',
#   '75.21.133.13'),
#  (654,
#   'Elizabeth Larson',
#   'michaelbailey@example.net',
#   '888 Gonzalez Dam Apt. 192',
#   'New Lisa',
#   'New Hampshire',
#   'Malawi',
#   '249-298-1044',
#   'Hard your use none. Upon product account blood this including least.',
#   '2005-09-18',
#   2133,
#   '2022-02-20 07:14:57.611240',
#   '2022-02-20 07:14:57.611241',
#   '213.22.20.218'),
#  (655,
#   'Pamela Case',
#   'rmcguire@example.com',
#   '6889 Fitzgerald Station Suite 941',
#   'Nelsonhaven',
#   'Arkansas',
#   'Romania',
#   '325.718.7175',
#   'Think technology nice understand behind reality.',
#   '2009-04-28',
#   1634,
#   '2022-02-20 07:14:57.611976',
#   '2022-02-20 07:14:57.611977',
#   '59.95.102.34'),
#  (656,
#   'Bradley Ramsey',
#   'myersellen@example.com',
#   '77615 Weaver Wall',
#   'Port Gregory',
#   'Massachusetts',
#   'United States Virgin Islands',
#   '809-796-5392',
#   'Any game inside page food maybe still. Body including affect four live '
#   'action.',
#   '1981-01-24',
#   1231,
#   '2022-02-20 07:14:57.612743',
#   '2022-02-20 07:14:57.612744',
#   '210.102.30.209'),
#  (657,
#   'Michael Herman',
#   'quinnautumn@example.com',
#   '42265 Smith Trace Apt. 943',
#   'Travisstad',
#   'Ohio',
#   'Guam',
#   '764-078-6037x953',
#   'Make difference yes something near. Until open fact sort job.',
#   '1911-04-21',
#   2013,
#   '2022-02-20 07:14:57.613527',
#   '2022-02-20 07:14:57.613528',
#   '174.102.68.145'),
#  (658,
#   'David Clark',
#   'williamlee@example.com',
#   '91793 Spears Groves',
#   'Joeshire',
#   'Oregon',
#   'Nepal',
#   '4705753285',
#   'Tell least short yard almost. Fight wind field right can step everyone.',
#   '1961-07-29',
#   2429,
#   '2022-02-20 07:14:57.614302',
#   '2022-02-20 07:14:57.614303',
#   '93.103.100.196'),
#  (659,
#   'Wesley Sanchez',
#   'pjuarez@example.net',
#   '35732 Nelson Drive Suite 433',
#   'Princefurt',
#   'Arkansas',
#   'Colombia',
#   '550.040.0263x44643',
#   'None manager kitchen thousand energy lose.',
#   '1943-06-17',
#   2082,
#   '2022-02-20 07:14:57.615037',
#   '2022-02-20 07:14:57.615038',
#   '111.26.163.215'),
#  (660,
#   'Mrs. Gabrielle Barrett',
#   'xwilson@example.com',
#   '8205 Gibson Ports',
#   'East Georgehaven',
#   'South Carolina',
#   'Netherlands',
#   '+1-564-939-8434x6873',
#   'Clearly statement election its various per. Author let strategy.',
#   '1943-09-25',
#   1185,
#   '2022-02-20 07:14:57.615777',
#   '2022-02-20 07:14:57.615779',
#   '8.169.117.5'),
#  (661,
#   'Brittany Rodriguez',
#   'xjackson@example.net',
#   '4926 Chen Loaf Apt. 418',
#   'Martinezland',
#   'Indiana',
#   'Kyrgyz Republic',
#   '5081937962',
#   'So financial seven kitchen. Short compare fill cause dog project.',
#   '2017-04-05',
#   1540,
#   '2022-02-20 07:14:57.616518',
#   '2022-02-20 07:14:57.616519',
#   '55.176.246.217'),
#  (662,
#   'Tony Russell',
#   'nathancrawford@example.com',
#   '069 Peterson Garden Apt. 248',
#   'Martinfurt',
#   'Wisconsin',
#   'United Kingdom',
#   '4351032631',
#   'Majority much collection say traditional. Impact fish girl find.',
#   '2007-07-28',
#   1681,
#   '2022-02-20 07:14:57.617313',
#   '2022-02-20 07:14:57.617314',
#   '211.131.252.111'),
#  (663,
#   'Peter Brown',
#   'nturner@example.com',
#   '6904 Flores Forest',
#   'North Joseph',
#   'Alabama',
#   'Slovenia',
#   '001-159-030-8616x248',
#   'Something yet break into. Small third particular quality save dream.',
#   '1999-05-02',
#   1237,
#   '2022-02-20 07:14:57.618015',
#   '2022-02-20 07:14:57.618016',
#   '87.65.12.158'),
#  (664,
#   'Jessica Perez',
#   'anna91@example.com',
#   '8254 Hannah Wall Suite 732',
#   'New Gregory',
#   'West Virginia',
#   'Philippines',
#   '587.774.0380x492',
#   'Table director feeling. Pretty daughter simple paper.',
#   '1967-12-01',
#   1541,
#   '2022-02-20 07:14:57.618697',
#   '2022-02-20 07:14:57.618698',
#   '179.104.100.81'),
#  (665,
#   'Amy Sullivan',
#   'grossmary@example.org',
#   '41653 Nancy Shoals',
#   'Michaelshire',
#   'Rhode Island',
#   'Somalia',
#   '807.875.8569x023',
#   'Let successful book onto wear responsibility.',
#   '1969-07-31',
#   1322,
#   '2022-02-20 07:14:57.619441',
#   '2022-02-20 07:14:57.619442',
#   '54.71.163.76'),
#  (666,
#   'William Nichols',
#   'eric11@example.org',
#   '807 Amber Rapid',
#   'South Briannamouth',
#   'Pennsylvania',
#   'Luxembourg',
#   '001-108-064-1148',
#   'Skin dog join already. Subject watch air bar deal.',
#   '2003-05-07',
#   1526,
#   '2022-02-20 07:14:57.620096',
#   '2022-02-20 07:14:57.620098',
#   '135.37.36.252'),
#  (667,
#   'Lisa Harrison',
#   'ashleycarter@example.com',
#   '77565 Thomas Islands Apt. 630',
#   'Emilytown',
#   'Georgia',
#   'Czech Republic',
#   '755.306.2535',
#   'Pressure top fly describe development possible.',
#   '1918-02-02',
#   1547,
#   '2022-02-20 07:14:57.620871',
#   '2022-02-20 07:14:57.620872',
#   '64.243.102.220'),
#  (668,
#   'Melody Chen',
#   'erin88@example.net',
#   '7503 Theodore Prairie Apt. 032',
#   'Lauraside',
#   'Georgia',
#   'Yemen',
#   '813.707.6199',
#   'Factor head again step role. One after film me environmental raise once.',
#   '2006-10-07',
#   1333,
#   '2022-02-20 07:14:57.621544',
#   '2022-02-20 07:14:57.621545',
#   '43.176.4.189'),
#  (669,
#   'Wanda Castillo',
#   'elizabethshields@example.com',
#   '3403 Steven Trail',
#   'Port Judyborough',
#   'North Carolina',
#   'Botswana',
#   '+1-768-457-3582x20432',
#   'Its for through event special. Take campaign event pick officer story '
#   'election.',
#   '2002-03-07',
#   1898,
#   '2022-02-20 07:14:57.622295',
#   '2022-02-20 07:14:57.622296',
#   '108.221.139.85'),
#  (670,
#   'Brandon Singh',
#   'juliefuller@example.org',
#   '092 Perry Valleys',
#   'Schmidtland',
#   'New York',
#   'Mauritius',
#   '+1-796-529-8552x428',
#   'Teach final personal able pattern room. Much against garden not spend '
#   'detail.',
#   '1948-03-15',
#   1183,
#   '2022-02-20 07:14:57.623089',
#   '2022-02-20 07:14:57.623090',
#   '91.135.98.73'),
#  (671,
#   'Nicholas Stevens',
#   'monica15@example.net',
#   '2340 William Summit Suite 269',
#   'Port Anthonychester',
#   'Idaho',
#   'Holy See (Vatican City State)',
#   '+1-566-104-4694',
#   'Free next partner unit summer our. Always military memory effect although '
#   'know.',
#   '1931-10-08',
#   1387,
#   '2022-02-20 07:14:57.623800',
#   '2022-02-20 07:14:57.623801',
#   '43.185.253.74'),
#  (672,
#   'Brenda Howell',
#   'rhonda61@example.org',
#   '4575 Stephanie Heights Suite 930',
#   'West Kristen',
#   'Louisiana',
#   'American Samoa',
#   '479-646-7845',
#   'Experience skill mother like win. Soon career leg recently feel.',
#   '1984-10-16',
#   1856,
#   '2022-02-20 07:14:57.624472',
#   '2022-02-20 07:14:57.624474',
#   '48.163.205.140'),
#  (673,
#   'Kristie Lane',
#   'christopher64@example.com',
#   '2615 Stewart Fords Apt. 061',
#   'Lake Chase',
#   'South Carolina',
#   'Turkmenistan',
#   '(817)016-3106x8759',
#   'Computer next degree never movie.',
#   '1993-05-03',
#   1688,
#   '2022-02-20 07:14:57.625154',
#   '2022-02-20 07:14:57.625156',
#   '187.59.95.185'),
#  (674,
#   'Daniel Orr',
#   'brooksronald@example.com',
#   '7278 Ramirez Avenue Apt. 027',
#   'Bergermouth',
#   'Missouri',
#   'Comoros',
#   '088-970-8829x1568',
#   'Grow letter garden type pick majority. How wait should build campaign.',
#   '1913-03-18',
#   1812,
#   '2022-02-20 07:14:57.625988',
#   '2022-02-20 07:14:57.625989',
#   '164.88.38.146'),
#  (675,
#   'Brian Moody',
#   'johnsonmonica@example.net',
#   '1301 Marshall Extensions Apt. 468',
#   'Scottmouth',
#   'New Hampshire',
#   'American Samoa',
#   '121.080.6788x893',
#   'In style rest age night. Affect somebody usually certain join increase.',
#   '2010-02-11',
#   1941,
#   '2022-02-20 07:14:57.626794',
#   '2022-02-20 07:14:57.626796',
#   '182.234.162.147'),
#  (676,
#   'Christopher Gonzalez',
#   'xhernandez@example.com',
#   '6990 Cassidy Mountains Suite 075',
#   'Bobbyhaven',
#   'Mississippi',
#   'Timor-Leste',
#   '001-034-589-0670',
#   'Probably put generation. Its head follow. Nation language air myself water.',
#   '1974-06-30',
#   1148,
#   '2022-02-20 07:14:57.627507',
#   '2022-02-20 07:14:57.627508',
#   '86.160.134.0'),
#  (677,
#   'Terry Taylor',
#   'vbraun@example.net',
#   '9750 Michelle Light',
#   'East Debra',
#   'Oklahoma',
#   'Falkland Islands (Malvinas)',
#   '(618)067-4475',
#   'Middle us field politics family language. Since success create under '
#   'budget.',
#   '2010-04-01',
#   2336,
#   '2022-02-20 07:14:57.628182',
#   '2022-02-20 07:14:57.628183',
#   '210.146.137.74'),
#  (678,
#   'Kenneth Wilkins',
#   'brittanyscott@example.com',
#   '8894 Leslie Harbor Apt. 574',
#   'Lake Heather',
#   'Michigan',
#   'Namibia',
#   '001-763-258-8716x04177',
#   'Friend visit play or generation edge.',
#   '1923-05-30',
#   1346,
#   '2022-02-20 07:14:57.629003',
#   '2022-02-20 07:14:57.629004',
#   '43.159.7.211'),
#  (679,
#   'William Johnson',
#   'qkennedy@example.net',
#   '3631 Munoz Path Suite 591',
#   'Lake Jamesstad',
#   'West Virginia',
#   'New Zealand',
#   '001-146-376-3579',
#   'Travel report share street traditional red young.',
#   '1956-11-15',
#   1385,
#   '2022-02-20 07:14:57.629731',
#   '2022-02-20 07:14:57.629732',
#   '85.155.147.186'),
#  (680,
#   'Toni Smith',
#   'irodriguez@example.org',
#   '7888 Daniel Locks',
#   'New Javier',
#   'Kentucky',
#   'French Guiana',
#   '001-093-811-3413',
#   'Quite main ten without really morning big.',
#   '1952-06-10',
#   1022,
#   '2022-02-20 07:14:57.630409',
#   '2022-02-20 07:14:57.630410',
#   '99.90.80.69'),
#  (681,
#   'Mr. Kevin Myers',
#   'ryan49@example.net',
#   '5340 Barr Square',
#   'Sherryville',
#   'Wyoming',
#   'Palau',
#   '922.860.2269',
#   'List do smile use avoid money also. Politics many consumer accept break '
#   'enter.',
#   '2005-11-25',
#   1640,
#   '2022-02-20 07:14:57.631099',
#   '2022-02-20 07:14:57.631100',
#   '212.35.56.99'),
#  (682,
#   'Jessica Johnson',
#   'gonzalezpaul@example.net',
#   '789 Victoria Field Apt. 796',
#   'Lake Jasmine',
#   'Tennessee',
#   'Kiribati',
#   '285-543-7964',
#   'Test campaign control law address within true small. Have arm tough.',
#   '2018-08-24',
#   1003,
#   '2022-02-20 07:14:57.631861',
#   '2022-02-20 07:14:57.631862',
#   '161.140.160.127'),
#  (683,
#   'Madison Cunningham',
#   'jeremy68@example.com',
#   '2387 Payne Forest',
#   'North Matthewport',
#   'New York',
#   'Lebanon',
#   '(822)646-6368x98769',
#   'Parent live effect increase allow personal economy. Us research conference.',
#   '1984-01-21',
#   1066,
#   '2022-02-20 07:14:57.632562',
#   '2022-02-20 07:14:57.632563',
#   '126.111.53.202'),
#  (684,
#   'Natalie Austin',
#   'tammybeasley@example.org',
#   '70582 Knight Road',
#   'Marksshire',
#   'Wyoming',
#   'Libyan Arab Jamahiriya',
#   '343-124-5988',
#   'Condition mission stage prepare hard clear can. Religious cultural should.',
#   '1983-12-02',
#   2186,
#   '2022-02-20 07:14:57.633348',
#   '2022-02-20 07:14:57.633349',
#   '186.96.215.206'),
#  (685,
#   'Anne Morris',
#   'davidedwards@example.org',
#   '39017 Nguyen Fords Apt. 446',
#   'New Karen',
#   'Colorado',
#   'Cameroon',
#   '001-001-928-3340x85742',
#   'Reality glass range shoulder surface. Training with participant kitchen or '
#   'job.',
#   '1985-05-19',
#   2459,
#   '2022-02-20 07:14:57.634119',
#   '2022-02-20 07:14:57.634120',
#   '12.108.204.203'),
#  (686,
#   'John Howell',
#   'karenjones@example.org',
#   '064 Sherman Harbors',
#   'East Jacobland',
#   'Michigan',
#   "Lao People's Democratic Republic",
#   '974.358.5844',
#   'Happen past science offer throughout ready Congress. Hotel upon speak '
#   'laugh.',
#   '1909-01-12',
#   2199,
#   '2022-02-20 07:14:57.634880',
#   '2022-02-20 07:14:57.634881',
#   '107.244.237.53'),
#  (687,
#   'David Wheeler',
#   'qwhite@example.com',
#   '133 Villa Plains',
#   'Codystad',
#   'New Mexico',
#   'Iceland',
#   '(276)785-4973x18298',
#   'Wide because up guess during policy cover. Argue board rate short really '
#   'court.',
#   '1910-10-21',
#   2419,
#   '2022-02-20 07:14:57.635596',
#   '2022-02-20 07:14:57.635597',
#   '128.220.227.28'),
#  (688,
#   'Amanda Campbell',
#   'janderson@example.com',
#   '183 Donaldson Motorway',
#   'Lake Devon',
#   'Kentucky',
#   'Belize',
#   '314-637-4642x809',
#   'Modern hard then hotel. Miss political election statement notice cost '
#   'ahead.',
#   '1955-09-08',
#   2209,
#   '2022-02-20 07:14:57.636305',
#   '2022-02-20 07:14:57.636306',
#   '151.63.225.17'),
#  (689,
#   'Tammie Harrison',
#   'angelahawkins@example.com',
#   '6494 Lori Light Suite 621',
#   'Moorefurt',
#   'Missouri',
#   'Micronesia',
#   '655-289-1498x38629',
#   'Much arrive treatment green. Tend analysis power feel.',
#   '1966-09-18',
#   2263,
#   '2022-02-20 07:14:57.637076',
#   '2022-02-20 07:14:57.637078',
#   '52.88.54.15'),
#  (690,
#   'Nicole Shepherd',
#   'byrddiana@example.com',
#   '9285 Cynthia Parkway',
#   'Jaredton',
#   'Hawaii',
#   'Lithuania',
#   '787.789.0769x119',
#   'Style company one little people at. Short before discover its stock unit.',
#   '1953-08-06',
#   1672,
#   '2022-02-20 07:14:57.637821',
#   '2022-02-20 07:14:57.637822',
#   '21.44.113.64'),
#  (691,
#   'Mrs. Rachel Coleman DVM',
#   'kylie89@example.net',
#   '3169 Kristin Burg',
#   'Port Michaelfurt',
#   'Arizona',
#   'Saint Pierre and Miquelon',
#   '001-265-375-2246x92534',
#   'Kitchen exactly minute question. Care many moment kind agency chair car.',
#   '1915-06-05',
#   1808,
#   '2022-02-20 07:14:57.638529',
#   '2022-02-20 07:14:57.638531',
#   '8.92.78.237'),
#  (692,
#   'Jacqueline Keith',
#   'xsmall@example.net',
#   '00136 Baker Summit Suite 153',
#   'North Debrahaven',
#   'Nevada',
#   'Bahrain',
#   '(630)308-4301x56921',
#   'Popular far almost natural store environmental. Security someone partner.',
#   '1933-12-29',
#   1561,
#   '2022-02-20 07:14:57.639299',
#   '2022-02-20 07:14:57.639301',
#   '6.115.213.24'),
#  (693,
#   'John Calderon',
#   'mary41@example.net',
#   '927 Hodges Way Suite 613',
#   'East Amy',
#   'Kentucky',
#   'Swaziland',
#   '2988599906',
#   'Cost firm ever realize finally throw. One side skill total size work why.',
#   '1949-09-21',
#   2183,
#   '2022-02-20 07:14:57.640007',
#   '2022-02-20 07:14:57.640008',
#   '24.176.83.161'),
#  (694,
#   'William Moore',
#   'jeremy71@example.org',
#   '61280 Melinda Point',
#   'Carterbury',
#   'Wisconsin',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   '+1-070-472-1121x09600',
#   'Financial newspaper way begin road democratic.',
#   '2012-11-11',
#   2271,
#   '2022-02-20 07:14:57.640694',
#   '2022-02-20 07:14:57.640696',
#   '137.85.169.2'),
#  (695,
#   'Teresa Santiago',
#   'christine25@example.org',
#   '39599 Castillo Manors',
#   'Davisstad',
#   'Wyoming',
#   'Antarctica (the territory South of 60 deg S)',
#   '2123032084',
#   'Investment together necessary shake when white significant democratic.',
#   '1946-12-14',
#   2323,
#   '2022-02-20 07:14:57.641395',
#   '2022-02-20 07:14:57.641396',
#   '57.63.37.75'),
#  (696,
#   'Stephanie Sanders DDS',
#   'allenkristen@example.net',
#   '874 Miller Spring',
#   'Phillipside',
#   'Nevada',
#   'Saint Barthelemy',
#   '151-777-9015x648',
#   'Design if mother somebody leg make. Eye any together short yard.',
#   '1916-04-17',
#   1671,
#   '2022-02-20 07:14:57.642154',
#   '2022-02-20 07:14:57.642155',
#   '103.215.190.1'),
#  (697,
#   'Christina Hunt',
#   'wjohnson@example.org',
#   '668 Smith Circles Suite 249',
#   'Davismouth',
#   'New Jersey',
#   'Haiti',
#   '198.294.1559x81805',
#   'Full early population herself receive itself. Country less she Mr must.',
#   '1931-09-01',
#   2456,
#   '2022-02-20 07:14:57.642911',
#   '2022-02-20 07:14:57.642912',
#   '164.224.244.209'),
#  (698,
#   'Renee Dean',
#   'carterandrew@example.com',
#   '438 Martin Route Suite 571',
#   'Davisshire',
#   'Arizona',
#   'Philippines',
#   '620-855-1409x0998',
#   'Have mean price. Just trip deep many town. To Mrs new how however drive.',
#   '2009-09-29',
#   2138,
#   '2022-02-20 07:14:57.643729',
#   '2022-02-20 07:14:57.643730',
#   '104.38.154.16'),
#  (699,
#   'Jeffrey Rodriguez',
#   'sandra36@example.com',
#   '187 Olson Cliffs Apt. 316',
#   'East Yolandamouth',
#   'Delaware',
#   'Cambodia',
#   '001-608-068-5999x02066',
#   'Realize discussion star popular change say whatever whole.',
#   '1944-08-20',
#   1296,
#   '2022-02-20 07:14:57.644425',
#   '2022-02-20 07:14:57.644427',
#   '167.202.77.193'),
#  (700,
#   'Nancy King',
#   'hoganjessica@example.net',
#   '194 Rodriguez Key Suite 639',
#   'Port Earlchester',
#   'Idaho',
#   'Germany',
#   '001-532-687-2125x49634',
#   'Artist instead must bag final health participant.',
#   '1917-12-19',
#   1110,
#   '2022-02-20 07:14:57.645182',
#   '2022-02-20 07:14:57.645184',
#   '110.16.224.190'),
#  (701,
#   'Samantha Jones',
#   'harry13@example.com',
#   '073 Ryan Parkways',
#   'Michellemouth',
#   'Texas',
#   'Dominica',
#   '+1-742-004-4490x42695',
#   'Agreement enough fly daughter popular nearly mention. You main down option '
#   'new.',
#   '1969-11-03',
#   2126,
#   '2022-02-20 07:14:57.645853',
#   '2022-02-20 07:14:57.645854',
#   '34.87.132.7'),
#  (702,
#   'Dawn Owens',
#   'ajohnston@example.org',
#   '7111 Ana Forge',
#   'Karinaport',
#   'Minnesota',
#   'Lebanon',
#   '(371)124-3153',
#   'Recently could throughout environment believe.',
#   '1923-12-13',
#   1711,
#   '2022-02-20 07:14:57.646517',
#   '2022-02-20 07:14:57.646518',
#   '108.100.164.223'),
#  (703,
#   'Ruth Rush',
#   'hsmith@example.net',
#   '880 Sampson Radial',
#   'New Heather',
#   'Virginia',
#   'Finland',
#   '354.819.2057',
#   'Lead beat allow beat development audience.',
#   '1949-04-29',
#   1125,
#   '2022-02-20 07:14:57.647234',
#   '2022-02-20 07:14:57.647236',
#   '80.12.109.233'),
#  (704,
#   'Hannah Mcneil',
#   'tiffanygomez@example.com',
#   '2305 Castaneda Haven Apt. 839',
#   'Saraburgh',
#   'Kansas',
#   'Turks and Caicos Islands',
#   '218.506.0376x538',
#   'Soldier detail enjoy minute stuff.',
#   '2021-07-20',
#   1914,
#   '2022-02-20 07:14:57.648002',
#   '2022-02-20 07:14:57.648003',
#   '15.66.204.146'),
#  (705,
#   'Diana Massey',
#   'williamschristian@example.net',
#   '25304 Buck Crossing',
#   'New Kathleenhaven',
#   'Colorado',
#   'Israel',
#   '001-574-064-0824',
#   'Big enter at nor culture. Top eat again probably start stage something '
#   'right.',
#   '1982-05-20',
#   2229,
#   '2022-02-20 07:14:57.648771',
#   '2022-02-20 07:14:57.648772',
#   '67.115.114.65'),
#  (706,
#   'Ronald Arnold',
#   'dbooth@example.net',
#   '550 Mary Run',
#   'Josephmouth',
#   'Louisiana',
#   'Lebanon',
#   '776-351-2045',
#   'Real city everything scientist receive production.',
#   '2006-05-19',
#   2136,
#   '2022-02-20 07:14:57.649460',
#   '2022-02-20 07:14:57.649462',
#   '50.182.229.199'),
#  (707,
#   'Taylor Holland',
#   'obuck@example.com',
#   '9024 Ronald Courts',
#   'New Judychester',
#   'South Carolina',
#   'Afghanistan',
#   '+1-457-087-8392x6774',
#   'Value suddenly attorney perhaps less stock very.',
#   '1996-10-14',
#   1782,
#   '2022-02-20 07:14:57.650127',
#   '2022-02-20 07:14:57.650128',
#   '135.61.207.71'),
#  (708,
#   'Robert Nelson',
#   'omitchell@example.net',
#   '281 Edward Estate Suite 108',
#   'West Timothyfort',
#   'Oregon',
#   'Guyana',
#   '(824)512-2928',
#   'Responsibility born officer. Night leave growth brother bill.',
#   '1947-04-27',
#   2000,
#   '2022-02-20 07:14:57.650828',
#   '2022-02-20 07:14:57.650829',
#   '199.37.150.216'),
#  (709,
#   'Lori Stewart',
#   'kristin59@example.net',
#   '73171 Harris Place Apt. 791',
#   'North Darylchester',
#   'Massachusetts',
#   'Guam',
#   '+1-332-072-9633x982',
#   'See daughter public carry choice young.',
#   '2020-01-04',
#   2141,
#   '2022-02-20 07:14:57.651526',
#   '2022-02-20 07:14:57.651528',
#   '92.130.158.107'),
#  (710,
#   'Robert Roberts',
#   'jenniferbell@example.com',
#   '59466 Sarah Haven',
#   'East Timothy',
#   'New Mexico',
#   'Saint Lucia',
#   '+1-625-253-9452x14596',
#   'Reason perhaps although more bring. Rich measure natural growth.',
#   '1926-10-05',
#   1839,
#   '2022-02-20 07:14:57.652285',
#   '2022-02-20 07:14:57.652286',
#   '39.87.131.205'),
#  (711,
#   'Ashley Yu',
#   'cynthia85@example.org',
#   '168 Natalie Creek',
#   'West Edward',
#   'Indiana',
#   'Ecuador',
#   '5009320155',
#   'Fear some imagine direction coach store test.',
#   '1934-12-14',
#   1788,
#   '2022-02-20 07:14:57.652918',
#   '2022-02-20 07:14:57.652919',
#   '26.52.102.223'),
#  (712,
#   'Connie Powell',
#   'morgan66@example.net',
#   '4687 Hammond Ridges',
#   'Downsburgh',
#   'Maine',
#   'United States of America',
#   '662.396.4617',
#   'Simply garden meeting media near. While say compare rather have former.',
#   '2008-08-08',
#   1649,
#   '2022-02-20 07:14:57.653615',
#   '2022-02-20 07:14:57.653617',
#   '176.111.252.57'),
#  (713,
#   'Amanda Sampson',
#   'gonzalezsuzanne@example.org',
#   '8515 Aaron Inlet Apt. 508',
#   'Charlesburgh',
#   'Utah',
#   'Panama',
#   '(728)901-1264',
#   'Hour organization cup stage agency young budget.',
#   '1948-06-26',
#   2155,
#   '2022-02-20 07:14:57.654355',
#   '2022-02-20 07:14:57.654356',
#   '45.253.148.231'),
#  (714,
#   'Alice Knapp',
#   'wheelerjames@example.com',
#   '3485 Michael Glen',
#   'Lake Teresatown',
#   'Nebraska',
#   'Liechtenstein',
#   '1371515577',
#   'Authority third this. Represent bad heavy least.',
#   '1931-11-01',
#   1571,
#   '2022-02-20 07:14:57.655075',
#   '2022-02-20 07:14:57.655076',
#   '81.78.27.43'),
#  (715,
#   'Paul Fernandez',
#   'natalie24@example.org',
#   '32302 Taylor Freeway',
#   'Davidberg',
#   'Montana',
#   'Sao Tome and Principe',
#   '1660669997',
#   'Certain single myself age event.',
#   '1939-10-21',
#   1990,
#   '2022-02-20 07:14:57.655748',
#   '2022-02-20 07:14:57.655749',
#   '34.154.248.134'),
#  (716,
#   'Kathleen Patel',
#   'thomas21@example.org',
#   '67980 Henson Islands Suite 994',
#   'South Matthewbury',
#   'Hawaii',
#   'Cocos (Keeling) Islands',
#   '878-793-1652x143',
#   'Energy thing young page. Experience on thought organization. Rich new '
#   'center.',
#   '2005-04-05',
#   2449,
#   '2022-02-20 07:14:57.656466',
#   '2022-02-20 07:14:57.656467',
#   '56.154.217.246'),
#  (717,
#   'Brittany Daugherty',
#   'saundersandrew@example.org',
#   '5896 Shawn Street Suite 436',
#   'Lake Benjamin',
#   'New Jersey',
#   'Oman',
#   '(386)619-1054',
#   'Successful tend least respond nature approach.',
#   '1974-12-02',
#   2296,
#   '2022-02-20 07:14:57.657186',
#   '2022-02-20 07:14:57.657187',
#   '39.244.80.134'),
#  (718,
#   'Brandon Nunez',
#   'katherineshaw@example.net',
#   '52865 Marshall Pike',
#   'Lake Stephen',
#   'Mississippi',
#   'Azerbaijan',
#   '+1-188-816-2396x8286',
#   'Suddenly member poor system lead all itself.',
#   '1927-11-02',
#   1029,
#   '2022-02-20 07:14:57.657943',
#   '2022-02-20 07:14:57.657944',
#   '28.120.90.110'),
#  (719,
#   'Allison Anderson MD',
#   'umunoz@example.org',
#   '7575 Sarah Isle Suite 236',
#   'West Johnland',
#   'Montana',
#   'Tunisia',
#   '(238)921-5224',
#   'Community dinner blue onto great. Us single marriage. Like me become '
#   'answer.',
#   '1987-07-08',
#   1159,
#   '2022-02-20 07:14:57.658669',
#   '2022-02-20 07:14:57.658670',
#   '51.29.236.27'),
#  (720,
#   'Cody Smith',
#   'nwest@example.org',
#   '8351 Berg Hill',
#   'South Nicoleshire',
#   'Michigan',
#   'Cocos (Keeling) Islands',
#   '(194)675-8253x648',
#   'Leader travel camera management. Resource he attention full trouble anyone.',
#   '1929-05-16',
#   2117,
#   '2022-02-20 07:14:57.659436',
#   '2022-02-20 07:14:57.659438',
#   '108.46.186.38'),
#  (721,
#   'Terry Cox',
#   'steven66@example.com',
#   '42896 Robinson Track',
#   'Yatesborough',
#   'Michigan',
#   'Niger',
#   '+1-463-329-6979x5528',
#   'Her need newspaper establish quality. Yet few way paper allow.',
#   '1978-04-13',
#   1704,
#   '2022-02-20 07:14:57.660341',
#   '2022-02-20 07:14:57.660343',
#   '151.27.138.87'),
#  (722,
#   'Michael Simpson',
#   'robertyoung@example.org',
#   '6015 Parker Parkways',
#   'Medinatown',
#   'Alabama',
#   'Iran',
#   '(820)429-5965',
#   'Item probably here senior our town brother drop.',
#   '1931-07-20',
#   1621,
#   '2022-02-20 07:14:57.661116',
#   '2022-02-20 07:14:57.661118',
#   '219.211.34.153'),
#  (723,
#   'Kristina Foster',
#   'waynelowery@example.org',
#   '40551 Troy Fields Apt. 034',
#   'Waltersburgh',
#   'Louisiana',
#   'Nepal',
#   '(838)880-8247x11878',
#   'Story may job community. Wonder address get bar.',
#   '2009-10-25',
#   1183,
#   '2022-02-20 07:14:57.661951',
#   '2022-02-20 07:14:57.661953',
#   '12.47.164.60'),
#  (724,
#   'Mary Decker',
#   'darren78@example.org',
#   '55966 Alexandra Brooks',
#   'Port Lindseyfurt',
#   'New York',
#   'Lithuania',
#   '(511)272-5730',
#   'Also tree father industry senior call. Occur wall education energy attack.',
#   '1994-08-22',
#   1075,
#   '2022-02-20 07:14:57.662638',
#   '2022-02-20 07:14:57.662639',
#   '117.39.237.47'),
#  (725,
#   'David Gonzalez',
#   'brandonromero@example.com',
#   '98381 Rachel Gardens Suite 713',
#   'Suzannebury',
#   'North Dakota',
#   'Northern Mariana Islands',
#   '885-864-2868x5167',
#   'Live Democrat focus kitchen teacher PM indicate.',
#   '1981-03-29',
#   1426,
#   '2022-02-20 07:14:57.663396',
#   '2022-02-20 07:14:57.663397',
#   '155.242.93.69'),
#  (726,
#   'Michael Walker',
#   'wrightcindy@example.net',
#   '7267 Kim Plains Suite 012',
#   'Porterberg',
#   'California',
#   'Gibraltar',
#   '362-170-2450',
#   'Loss analysis between per stuff room. Out ago sing production your.',
#   '1987-06-11',
#   1833,
#   '2022-02-20 07:14:57.664219',
#   '2022-02-20 07:14:57.664221',
#   '176.169.89.228'),
#  (727,
#   'Natalie Ellis',
#   'kevin16@example.com',
#   '7153 Angela Falls',
#   'East Davidburgh',
#   'Texas',
#   'Saint Kitts and Nevis',
#   '5667328759',
#   'Last nation employee through.',
#   '2007-06-20',
#   1898,
#   '2022-02-20 07:14:57.664871',
#   '2022-02-20 07:14:57.664872',
#   '124.142.81.231'),
#  (728,
#   'John Rodriguez',
#   'rebecca89@example.net',
#   '76354 Kristin Parkways',
#   'Sharpview',
#   'New Jersey',
#   'Bhutan',
#   '+1-620-314-7557x1841',
#   'Low who character natural run high explain college.',
#   '1962-02-08',
#   2453,
#   '2022-02-20 07:14:57.665722',
#   '2022-02-20 07:14:57.665723',
#   '202.92.39.64'),
#  (729,
#   'Craig Reyes',
#   'susan73@example.com',
#   '937 Bryan Alley Apt. 349',
#   'East Dianamouth',
#   'Minnesota',
#   'Iraq',
#   '001-164-562-5311x99757',
#   'State close dinner movement capital.',
#   '1965-01-19',
#   1737,
#   '2022-02-20 07:14:57.666410',
#   '2022-02-20 07:14:57.666411',
#   '171.199.168.53'),
#  (730,
#   'Paige Rhodes',
#   'waderobert@example.com',
#   '15305 Amanda Place',
#   'West Sean',
#   'Wyoming',
#   'Burkina Faso',
#   '001-054-118-0570x7532',
#   'Good miss inside be. Cut his perform only two beyond.',
#   '1940-06-05',
#   1806,
#   '2022-02-20 07:14:57.667163',
#   '2022-02-20 07:14:57.667164',
#   '52.149.159.116'),
#  (731,
#   'Austin Stevens PhD',
#   'codyzavala@example.org',
#   '88420 Dorsey Brooks Apt. 074',
#   'Lake Mary',
#   'Minnesota',
#   'Mexico',
#   '0740480743',
#   'Avoid hold voice easy child gun inside. Research final end stand study.',
#   '1956-01-08',
#   1254,
#   '2022-02-20 07:14:57.667962',
#   '2022-02-20 07:14:57.667963',
#   '137.127.98.165'),
#  (732,
#   'Alicia Smith',
#   'belleric@example.org',
#   '318 Lopez Shore Apt. 880',
#   'West Daniel',
#   'Vermont',
#   'Kiribati',
#   '400-522-6354x174',
#   'Will husband interest she believe benefit. Require his a real usually yard.',
#   '1909-04-08',
#   1999,
#   '2022-02-20 07:14:57.668743',
#   '2022-02-20 07:14:57.668744',
#   '58.226.0.17'),
#  (733,
#   'Sean Wright',
#   'nicole19@example.com',
#   '5639 Morgan Wells',
#   'Lake Andremouth',
#   'South Carolina',
#   'Portugal',
#   '570-325-1567x08744',
#   'Candidate per others report argue. Member how campaign.',
#   '1916-06-04',
#   1309,
#   '2022-02-20 07:14:57.669435',
#   '2022-02-20 07:14:57.669436',
#   '3.118.184.91'),
#  (734,
#   'Julie Nguyen',
#   'cassandrameyer@example.net',
#   '44701 Sullivan Square Suite 248',
#   'East David',
#   'Vermont',
#   'Cameroon',
#   '001-233-724-7057',
#   'Your contain piece coach mission religious. Dinner because side.',
#   '2018-05-21',
#   2219,
#   '2022-02-20 07:14:57.670194',
#   '2022-02-20 07:14:57.670195',
#   '211.190.30.207'),
#  (735,
#   'Tricia Parker',
#   'jonathan05@example.com',
#   '07647 Andrea Turnpike',
#   'Grahamburgh',
#   'Georgia',
#   'Guatemala',
#   '183-946-6139x6854',
#   'Catch indicate information onto including range thing.',
#   '2020-08-05',
#   1389,
#   '2022-02-20 07:14:57.670879',
#   '2022-02-20 07:14:57.670880',
#   '59.231.215.23'),
#  (736,
#   'Samantha Krause',
#   'reidruben@example.net',
#   '55806 Justin Loaf',
#   'Marystad',
#   'Rhode Island',
#   'Armenia',
#   '464-549-0127x42283',
#   'Couple store admit coach federal local. International per also home.',
#   '1942-04-09',
#   1400,
#   '2022-02-20 07:14:57.671635',
#   '2022-02-20 07:14:57.671636',
#   '105.246.143.250'),
#  (737,
#   'Brenda Smith',
#   'williamspears@example.net',
#   '35733 Williams Drives',
#   'South Matthew',
#   'Oklahoma',
#   'Western Sahara',
#   '(573)995-4670',
#   'Fire away between simple local. Lawyer laugh seat truth.',
#   '2007-07-15',
#   1185,
#   '2022-02-20 07:14:57.672470',
#   '2022-02-20 07:14:57.672472',
#   '205.49.35.103'),
#  (738,
#   'Brian Newton',
#   'jamesjacob@example.org',
#   '46824 Jennifer Burgs Apt. 697',
#   'Laurenstad',
#   'Georgia',
#   'France',
#   '(099)163-1420x502',
#   'Add protect up quite expert. Call before ball.',
#   '1922-05-08',
#   1072,
#   '2022-02-20 07:14:57.673291',
#   '2022-02-20 07:14:57.673293',
#   '72.22.8.158'),
#  (739,
#   'Angela Holland',
#   'mark74@example.org',
#   '03076 Jessica Ferry Apt. 844',
#   'Lake Bethany',
#   'North Dakota',
#   'Rwanda',
#   '(550)327-9715x4201',
#   'Everyone fast at floor meet. Top example doctor method even girl open '
#   'central.',
#   '1913-05-17',
#   2232,
#   '2022-02-20 07:14:57.674008',
#   '2022-02-20 07:14:57.674009',
#   '47.204.96.242'),
#  (740,
#   'Stephen Grant',
#   'wenglish@example.net',
#   '7356 William Fords Suite 975',
#   'Alexiston',
#   'Iowa',
#   'Denmark',
#   '001-960-829-1903',
#   'Trip benefit unit himself Mr book. Whom forget between military foreign.',
#   '1916-11-27',
#   1711,
#   '2022-02-20 07:14:57.674774',
#   '2022-02-20 07:14:57.674775',
#   '217.121.229.125'),
#  (741,
#   'Mitchell Perez',
#   'fitzgeraldmelissa@example.org',
#   '338 Thompson Turnpike',
#   'North Dennis',
#   'New Jersey',
#   'Gabon',
#   '249-615-3082',
#   'Account will suffer baby. Bill spend deal watch service hair.',
#   '2017-08-16',
#   1231,
#   '2022-02-20 07:14:57.675580',
#   '2022-02-20 07:14:57.675582',
#   '211.203.29.119'),
#  (742,
#   'Lindsay Martin',
#   'melissatorres@example.com',
#   '7025 Daniel Stravenue',
#   'Rogersfort',
#   'California',
#   'Cocos (Keeling) Islands',
#   '894-612-6578x3134',
#   'Sound couple try. Century anyone effect war. Reach north face hand now.',
#   '1978-04-02',
#   1748,
#   '2022-02-20 07:14:57.676399',
#   '2022-02-20 07:14:57.676400',
#   '130.84.120.227'),
#  (743,
#   'John Holmes',
#   'hughesmichael@example.org',
#   '10243 Brooks Run Suite 646',
#   'South Amanda',
#   'Mississippi',
#   'Guyana',
#   '+1-735-866-9201',
#   'Make eight want improve around. Wonder poor you receive begin say line.',
#   '1964-11-25',
#   1893,
#   '2022-02-20 07:14:57.677180',
#   '2022-02-20 07:14:57.677181',
#   '60.216.1.145'),
#  (744,
#   'Brooke Neal',
#   'christopher82@example.net',
#   '850 Elizabeth Forge Apt. 885',
#   'Vasquezland',
#   'Missouri',
#   'Burkina Faso',
#   '(635)705-1418x684',
#   'Employee direction play most third relationship.',
#   '1945-07-08',
#   2292,
#   '2022-02-20 07:14:57.677942',
#   '2022-02-20 07:14:57.677944',
#   '8.191.252.159'),
#  (745,
#   'Eileen Aguilar',
#   'fgarcia@example.org',
#   '65388 Kristin Valleys',
#   'Lake Erinberg',
#   'Minnesota',
#   'Norfolk Island',
#   '+1-055-629-2926x3232',
#   'Effect wish wish station little. Check key face talk.',
#   '1906-09-04',
#   1934,
#   '2022-02-20 07:14:57.678640',
#   '2022-02-20 07:14:57.678642',
#   '31.134.241.218'),
#  (746,
#   'Robert Anderson',
#   'richmichael@example.org',
#   '242 Browning Pines',
#   'West Kimberlybury',
#   'Wyoming',
#   'Poland',
#   '+1-041-908-1610',
#   'Business lot friend threat court political key. Magazine number study can '
#   'town.',
#   '1938-08-06',
#   2094,
#   '2022-02-20 07:14:57.679409',
#   '2022-02-20 07:14:57.679410',
#   '69.234.191.109'),
#  (747,
#   'Stephanie Parker',
#   'obrienmark@example.net',
#   '9620 Derek Burg Suite 205',
#   'Ramirezbury',
#   'Kansas',
#   'Singapore',
#   '614-115-3414',
#   'Light identify maintain. Movie why guess interview office attack build.',
#   '1927-08-31',
#   1425,
#   '2022-02-20 07:14:57.680190',
#   '2022-02-20 07:14:57.680192',
#   '168.205.229.18'),
#  (748,
#   'Samantha Stanton',
#   'belinda64@example.org',
#   '84465 Jackie Coves',
#   'Johnsonport',
#   'Delaware',
#   'Central African Republic',
#   '(248)121-3044x5746',
#   'Bed discussion work show necessary evening.',
#   '1907-12-19',
#   1344,
#   '2022-02-20 07:14:57.680888',
#   '2022-02-20 07:14:57.680889',
#   '119.229.123.26'),
#  (749,
#   'Christopher Macias',
#   'josephturner@example.com',
#   '47352 Peterson Burgs Suite 343',
#   'West Tammyhaven',
#   'South Carolina',
#   'Burundi',
#   '363-337-6278',
#   'Land market story throw others scientist. Agent girl believe magazine.',
#   '1985-06-23',
#   1767,
#   '2022-02-20 07:14:57.681664',
#   '2022-02-20 07:14:57.681665',
#   '95.171.240.180'),
#  (750,
#   'Julie Moon',
#   'brianarmstrong@example.org',
#   '770 George Via Apt. 210',
#   'Nguyenhaven',
#   'Delaware',
#   'Guinea-Bissau',
#   '(629)745-0952x576',
#   'Society situation sport fine. Unit likely paper us candidate own agent '
#   'group.',
#   '2017-06-06',
#   1804,
#   '2022-02-20 07:14:57.682449',
#   '2022-02-20 07:14:57.682450',
#   '50.194.64.125'),
#  (751,
#   'Bobby Thomas',
#   'morenocolton@example.org',
#   '020 Eric Lake Suite 633',
#   'North Teresatown',
#   'Pennsylvania',
#   'Burkina Faso',
#   '+1-555-169-5643',
#   'Situation chair itself need lawyer. Indicate game care prepare poor event.',
#   '1996-06-16',
#   2287,
#   '2022-02-20 07:14:57.683212',
#   '2022-02-20 07:14:57.683214',
#   '139.104.26.211'),
#  (752,
#   'Rebecca Reilly',
#   'qwatson@example.com',
#   '989 Ethan Meadow',
#   'Markland',
#   'Montana',
#   'Mozambique',
#   '234.893.2131x864',
#   'Research point officer shake modern. Exactly interest fund. Defense unit '
#   'us.',
#   '1985-01-05',
#   1898,
#   '2022-02-20 07:14:57.683909',
#   '2022-02-20 07:14:57.683910',
#   '129.181.37.113'),
#  (753,
#   'Adam Molina',
#   'christine87@example.org',
#   '70291 Amy Mountains',
#   'Choiberg',
#   'Missouri',
#   'Switzerland',
#   '633.349.8583x63622',
#   'Character speech outside center police. Feeling hotel moment middle whose '
#   'door.',
#   '2007-03-02',
#   2096,
#   '2022-02-20 07:14:57.684648',
#   '2022-02-20 07:14:57.684649',
#   '197.158.140.19'),
#  (754,
#   'Brian Arnold',
#   'tannerkim@example.org',
#   '2654 Troy Alley Apt. 376',
#   'Robertburgh',
#   'Rhode Island',
#   'Samoa',
#   '897.757.3320',
#   'Tv southern sign sea outside military win. Easy build increase.',
#   '1996-02-06',
#   2291,
#   '2022-02-20 07:14:57.685437',
#   '2022-02-20 07:14:57.685438',
#   '119.205.213.114'),
#  (755,
#   'John Wilcox',
#   'floresnicholas@example.org',
#   '34893 Beard Shore Suite 253',
#   'South Kimberlyland',
#   'Michigan',
#   'Spain',
#   '884.997.1526',
#   'State open blue rich ten through energy. Pattern state director save base.',
#   '1907-09-03',
#   2487,
#   '2022-02-20 07:14:57.686229',
#   '2022-02-20 07:14:57.686231',
#   '151.107.62.157'),
#  (756,
#   'Bradley Newman',
#   'ulogan@example.com',
#   '534 Mann Via Apt. 901',
#   'Jessicahaven',
#   'New Mexico',
#   'Chad',
#   '126.522.4218x579',
#   'Key among face difficult treatment. Fear sell show scientist similar.',
#   '1952-02-09',
#   2347,
#   '2022-02-20 07:14:57.686968',
#   '2022-02-20 07:14:57.686970',
#   '49.76.134.30'),
#  (757,
#   'Ariana Coleman',
#   'michelle14@example.net',
#   '12290 Dennis Hill',
#   'South Desireebury',
#   'New Hampshire',
#   'Comoros',
#   '987.718.1861x2125',
#   'Big education whom financial actually reflect newspaper begin.',
#   '1968-08-31',
#   1051,
#   '2022-02-20 07:14:57.687632',
#   '2022-02-20 07:14:57.687633',
#   '204.35.68.103'),
#  (758,
#   'Joseph Williams',
#   'fblack@example.net',
#   '26210 Sharon Passage',
#   'Smithchester',
#   'North Carolina',
#   'Martinique',
#   '+1-846-416-8047',
#   'Someone soldier two prepare security eye. Candidate carry build until then.',
#   '1917-02-27',
#   1820,
#   '2022-02-20 07:14:57.688350',
#   '2022-02-20 07:14:57.688352',
#   '143.216.123.94'),
#  (759,
#   'John Hanson',
#   'harold99@example.com',
#   '130 Turner Divide Suite 410',
#   'West Erikchester',
#   'Massachusetts',
#   'Albania',
#   '929.644.1257x345',
#   'Interview him soldier. Himself sound mention land newspaper leader.',
#   '1995-04-17',
#   2454,
#   '2022-02-20 07:14:57.689063',
#   '2022-02-20 07:14:57.689064',
#   '133.227.118.236'),
#  (760,
#   'Steven Greene',
#   'vbennett@example.com',
#   '615 Briana Unions',
#   'Ericborough',
#   'Montana',
#   'Reunion',
#   '+1-175-635-0119x02245',
#   'Lose increase without push seat military reveal wonder.',
#   '1930-11-22',
#   1292,
#   '2022-02-20 07:14:57.689763',
#   '2022-02-20 07:14:57.689764',
#   '170.167.57.193'),
#  (761,
#   'Christopher Perez',
#   'muellertammy@example.org',
#   '613 Cherry Via',
#   'Julianside',
#   'Alabama',
#   'Singapore',
#   '(370)902-6822x100',
#   'Myself summer director support which feel.',
#   '1970-12-17',
#   1506,
#   '2022-02-20 07:14:57.690514',
#   '2022-02-20 07:14:57.690515',
#   '110.30.35.247'),
#  (762,
#   'Steven Best',
#   'angel14@example.com',
#   '065 Jessica Island Apt. 629',
#   'Jenniferstad',
#   'Arkansas',
#   'Denmark',
#   '600.907.8522x5603',
#   'Mother by certain strong program television success.',
#   '1934-08-21',
#   2292,
#   '2022-02-20 07:14:57.691184',
#   '2022-02-20 07:14:57.691185',
#   '119.241.58.35'),
#  (763,
#   'Timothy Vaughn',
#   'mark04@example.net',
#   '12548 Duncan Terrace',
#   'West Sydney',
#   'North Dakota',
#   'India',
#   '582.559.3422x31068',
#   'Entire doctor blood back machine feeling. Age various inside leader.',
#   '2018-11-11',
#   1247,
#   '2022-02-20 07:14:57.691919',
#   '2022-02-20 07:14:57.691921',
#   '15.13.116.156'),
#  (764,
#   'Scott Frank',
#   'isloan@example.org',
#   '5560 Johnson Burg',
#   'South Joshuamouth',
#   'Alaska',
#   'Maldives',
#   '856.521.6414',
#   'Case side drive culture. Hair air water ability believe.',
#   '1942-01-02',
#   2347,
#   '2022-02-20 07:14:57.692668',
#   '2022-02-20 07:14:57.692669',
#   '23.222.132.237'),
#  (765,
#   'Rachel Williams',
#   'rogersmisty@example.net',
#   '613 Sharp Freeway',
#   'Nelsonton',
#   'California',
#   'Western Sahara',
#   '327.913.9807x81002',
#   'Edge hot itself skin media then. Amount run charge provide attention.',
#   '1913-07-21',
#   1807,
#   '2022-02-20 07:14:57.693472',
#   '2022-02-20 07:14:57.693473',
#   '87.202.87.14'),
#  (766,
#   'Wesley Smith',
#   'stonejimmy@example.net',
#   '9193 Amanda Row',
#   'Lisastad',
#   'Georgia',
#   'Fiji',
#   '001-805-099-6962x6795',
#   'Call challenge front perform discussion. Up discover save physical.',
#   '2017-02-17',
#   2091,
#   '2022-02-20 07:14:57.694198',
#   '2022-02-20 07:14:57.694199',
#   '129.57.6.254'),
#  (767,
#   'Megan Ford',
#   'kimberlywilliams@example.net',
#   '51574 Christopher Stream',
#   'Elizabethfort',
#   'South Carolina',
#   'Slovenia',
#   '044.041.6126',
#   'Responsibility dinner reduce second all. Week interview tell various time '
#   'blue.',
#   '2014-04-10',
#   1123,
#   '2022-02-20 07:14:57.694942',
#   '2022-02-20 07:14:57.694943',
#   '123.128.241.42'),
#  (768,
#   'Rebecca Smith',
#   'tiffanyturner@example.net',
#   '4196 Robert Burg',
#   'Port David',
#   'Louisiana',
#   'Palau',
#   '+1-224-845-1060',
#   'New collection yes city back. Board paper speech here full indicate night '
#   'let.',
#   '1998-03-01',
#   1708,
#   '2022-02-20 07:14:57.695669',
#   '2022-02-20 07:14:57.695670',
#   '113.247.127.84'),
#  (769,
#   'Gail Martin',
#   'qwilson@example.net',
#   '59780 Juan Hill',
#   'West James',
#   'Virginia',
#   'Norway',
#   '717.527.5360x278',
#   'Form add personal age share play relate dinner. Once society up best lose.',
#   '1933-07-27',
#   1108,
#   '2022-02-20 07:14:57.696406',
#   '2022-02-20 07:14:57.696407',
#   '139.62.106.157'),
#  (770,
#   'Jeremy Ellis',
#   'johnrussell@example.com',
#   '44992 Kenneth Stream Apt. 934',
#   'East Taylor',
#   'Maryland',
#   'Palestinian Territory',
#   '480.049.5187',
#   'Perhaps participant accept help per position last Mr.',
#   '1983-04-20',
#   1592,
#   '2022-02-20 07:14:57.697137',
#   '2022-02-20 07:14:57.697138',
#   '35.138.254.56'),
#  (771,
#   'George Wells',
#   'hsmith@example.net',
#   '695 Andrew Mountain Suite 947',
#   'Johnsonborough',
#   'Alaska',
#   'San Marino',
#   '558.877.6425',
#   'One purpose carry image heart might.',
#   '1962-11-26',
#   1891,
#   '2022-02-20 07:14:57.697870',
#   '2022-02-20 07:14:57.697871',
#   '40.45.133.43'),
#  (772,
#   'Steven Walker',
#   'robertvega@example.com',
#   '77626 Samuel Tunnel',
#   'Danielchester',
#   'Pennsylvania',
#   'United Arab Emirates',
#   '213.429.5648',
#   'Car mind scientist recently class defense.',
#   '1916-08-09',
#   1113,
#   '2022-02-20 07:14:57.698596',
#   '2022-02-20 07:14:57.698597',
#   '143.178.72.88'),
#  (773,
#   'Kelli King',
#   'valerie40@example.org',
#   '02452 Rachel Trail Apt. 499',
#   'New Kimberly',
#   'South Carolina',
#   'Monaco',
#   '7201053077',
#   'Action glass turn partner live hit.',
#   '1993-11-13',
#   2073,
#   '2022-02-20 07:14:57.699264',
#   '2022-02-20 07:14:57.699266',
#   '101.103.165.208'),
#  (774,
#   'Anthony Contreras',
#   'zperez@example.org',
#   '6310 Richards Shore',
#   'North Beckyburgh',
#   'Wyoming',
#   'French Southern Territories',
#   '878.388.0104',
#   'Despite detail among against. Traditional something much.',
#   '1945-11-15',
#   2474,
#   '2022-02-20 07:14:57.699957',
#   '2022-02-20 07:14:57.699958',
#   '26.17.11.245'),
#  (775,
#   'Megan Chang',
#   'icrane@example.com',
#   '41035 Charles Valley Suite 175',
#   'Kathleenmouth',
#   'Arkansas',
#   'Belarus',
#   '613.674.5957',
#   'Subject film full quite might body brother.',
#   '1928-11-14',
#   2195,
#   '2022-02-20 07:14:57.700637',
#   '2022-02-20 07:14:57.700639',
#   '54.36.68.170'),
#  (776,
#   'Victoria Walker',
#   'michael07@example.net',
#   '8322 Cruz Loop Suite 419',
#   'Reginabury',
#   'Missouri',
#   'Isle of Man',
#   '342.763.7436',
#   'Be time direction. Establish bad foreign result family Democrat teach.',
#   '1972-07-12',
#   2175,
#   '2022-02-20 07:14:57.701374',
#   '2022-02-20 07:14:57.701376',
#   '180.125.1.93'),
#  (777,
#   'Amanda Gray',
#   'willischristopher@example.net',
#   '969 Phillip River Suite 396',
#   'East Jasonville',
#   'South Dakota',
#   'Russian Federation',
#   '845.002.2951x71726',
#   'Maybe compare main drop get word. Life research much record.',
#   '2015-05-01',
#   2185,
#   '2022-02-20 07:14:57.702318',
#   '2022-02-20 07:14:57.702319',
#   '139.156.87.77'),
#  (778,
#   'Felicia Edwards',
#   'kathleen32@example.com',
#   '924 Donald Ville Apt. 476',
#   'Port Charlesland',
#   'Vermont',
#   'Somalia',
#   '(059)577-9722',
#   'Focus benefit wide control will dark.',
#   '1933-01-12',
#   1569,
#   '2022-02-20 07:14:57.702995',
#   '2022-02-20 07:14:57.702996',
#   '47.174.211.97'),
#  (779,
#   'Adrian Brooks',
#   'pedro62@example.com',
#   '926 Arias Unions Suite 628',
#   'Lake Matthew',
#   'California',
#   'Zimbabwe',
#   '(547)845-1604x03046',
#   'Unit true interest if suggest foot leader. Couple head fire very look '
#   'eight.',
#   '1922-04-19',
#   1090,
#   '2022-02-20 07:14:57.703712',
#   '2022-02-20 07:14:57.703713',
#   '69.191.202.251'),
#  (780,
#   'Leslie Gibson',
#   'chadblake@example.com',
#   '89638 Scott Crescent Apt. 837',
#   'Greershire',
#   'Florida',
#   'Nigeria',
#   '001-711-9116',
#   'Important book today member stage either. Require whose rest.',
#   '2011-11-04',
#   1054,
#   '2022-02-20 07:14:57.704511',
#   '2022-02-20 07:14:57.704513',
#   '32.143.189.14'),
#  (781,
#   'Alfred David',
#   'rsandoval@example.org',
#   '972 Riddle Village Suite 252',
#   'East Jade',
#   'New York',
#   'Papua New Guinea',
#   '+1-885-586-4704x48119',
#   'Tax run right word which. Determine without per size often stop push.',
#   '1929-01-30',
#   1793,
#   '2022-02-20 07:14:57.705303',
#   '2022-02-20 07:14:57.705304',
#   '91.48.109.67'),
#  (782,
#   'Sharon Allen',
#   'jared05@example.com',
#   '07855 Moore Ferry Apt. 256',
#   'Elizabethmouth',
#   'Montana',
#   'Russian Federation',
#   '(665)672-3108x1577',
#   'Through leader me success take meeting.',
#   '1973-05-25',
#   2087,
#   '2022-02-20 07:14:57.706060',
#   '2022-02-20 07:14:57.706061',
#   '65.234.60.27'),
#  (783,
#   'Sarah Smith',
#   'julia89@example.net',
#   '34349 Isaac Valley Apt. 843',
#   'East Whitney',
#   'Montana',
#   'Antigua and Barbuda',
#   '+1-909-750-3519',
#   'Fish tend service impact support price pick. Brother leg your cover.',
#   '2016-03-06',
#   1364,
#   '2022-02-20 07:14:57.706817',
#   '2022-02-20 07:14:57.706818',
#   '15.73.125.86'),
#  (784,
#   'Christina Montgomery',
#   'phyllis24@example.net',
#   '7107 Travis Creek',
#   'New Donald',
#   'Washington',
#   'Egypt',
#   '282.145.0755',
#   'Choice head almost participant. They method dog money. Least million '
#   'suddenly.',
#   '1933-06-23',
#   1855,
#   '2022-02-20 07:14:57.707590',
#   '2022-02-20 07:14:57.707591',
#   '2.41.254.249'),
#  (785,
#   'Lindsey Jones',
#   'pierceholly@example.net',
#   '20293 Mcdonald Brooks Apt. 331',
#   'Benjaminberg',
#   'Tennessee',
#   'Bosnia and Herzegovina',
#   '605.554.2104x73193',
#   'Back address only finish. Manager pick election.',
#   '2005-02-01',
#   1748,
#   '2022-02-20 07:14:57.708465',
#   '2022-02-20 07:14:57.708467',
#   '50.49.9.90'),
#  (786,
#   'Mrs. Jill Howard',
#   'johnsonjuan@example.com',
#   '15421 Bell Courts',
#   'Ethanside',
#   'Colorado',
#   'Lebanon',
#   '(723)890-0962x94590',
#   'Early environment blood wish. Before most food career painting would term '
#   'ever.',
#   '2020-07-07',
#   2058,
#   '2022-02-20 07:14:57.709292',
#   '2022-02-20 07:14:57.709293',
#   '130.109.161.43'),
#  (787,
#   'Donna Arias',
#   'ecooper@example.net',
#   '057 Thomas Court',
#   'East Jenniferville',
#   'Utah',
#   'Bahrain',
#   '778.455.9609',
#   'Our technology future anything social happen simply.',
#   '1924-07-20',
#   2139,
#   '2022-02-20 07:14:57.709988',
#   '2022-02-20 07:14:57.709989',
#   '132.90.156.103'),
#  (788,
#   'Jason Stanley',
#   'tammy18@example.com',
#   '8246 Lyons Ford',
#   'New Ronald',
#   'Pennsylvania',
#   'Pakistan',
#   '8622596104',
#   'Role kid raise lead. Receive key front light soon. Be effort expect south.',
#   '1986-12-09',
#   2045,
#   '2022-02-20 07:14:57.710694',
#   '2022-02-20 07:14:57.710695',
#   '208.129.43.25'),
#  (789,
#   'Diana Powell',
#   'bkelley@example.com',
#   '920 Jim River',
#   'West Ricky',
#   'South Carolina',
#   'Georgia',
#   '001-286-252-4636x73847',
#   'Impact very away. Mention something second spend.',
#   '1929-02-12',
#   1118,
#   '2022-02-20 07:14:57.711382',
#   '2022-02-20 07:14:57.711383',
#   '78.52.80.175'),
#  (790,
#   'Sean Davis',
#   'robert55@example.com',
#   '860 Travis Alley',
#   'Port Paul',
#   'New York',
#   'Guadeloupe',
#   '080.619.1987x209',
#   'Help no relate push. Fine two human simple. Teach population clear enjoy.',
#   '2004-03-10',
#   1255,
#   '2022-02-20 07:14:57.712046',
#   '2022-02-20 07:14:57.712047',
#   '21.29.199.101'),
#  (791,
#   'Christopher Patton',
#   'jenniferblack@example.com',
#   '70218 Caroline Mission',
#   'South William',
#   'Montana',
#   'Macedonia',
#   '969.637.3425x63370',
#   'It view visit tough leg nearly close market.',
#   '1987-03-15',
#   1590,
#   '2022-02-20 07:14:57.712781',
#   '2022-02-20 07:14:57.712782',
#   '40.234.199.219'),
#  (792,
#   'Patrick York',
#   'ssmith@example.net',
#   '902 Ford Corners',
#   'South Maria',
#   'Louisiana',
#   'Afghanistan',
#   '907-728-9731x039',
# ...
#   '1972-04-19',
#   1708,
#   '2022-02-20 07:14:57.840949',
#   '2022-02-20 07:14:57.840950',
#   '16.178.196.221'),
#  (953,
#   'Leslie Mendoza',
#   'mary20@example.org',
#   '562 Johnson Branch',
#   'Lake Richard',
#   'Indiana',
#   'Bolivia',
#   '342-076-4516x9801',
#   'Moment project describe recently owner. Subject president car only.',
#   '2001-11-25',
#   1472,
#   '2022-02-20 07:14:57.841651',
#   '2022-02-20 07:14:57.841652',
#   '144.58.207.144'),
#  (954,
#   'Kenneth Martin DDS',
#   'huffcarla@example.net',
#   '8289 Evan Glens',
#   'Jamesside',
#   'Missouri',
#   'Rwanda',
#   '979-300-6055',
#   'Training relate factor street development economy beat. Form more person '
#   'send.',
#   '1977-11-02',
#   2466,
#   '2022-02-20 07:14:57.842447',
#   '2022-02-20 07:14:57.842448',
#   '107.95.248.134'),
#  (955,
#   'Juan Miller',
#   'brandy84@example.com',
#   '29517 Washington Shoal',
#   'Marymouth',
#   'Delaware',
#   'Mayotte',
#   '001-457-412-9705x52246',
#   'Resource actually middle positive student. World scene plan few field.',
#   '1937-01-20',
#   1860,
#   '2022-02-20 07:14:57.843148',
#   '2022-02-20 07:14:57.843150',
#   '192.133.2.147'),
#  (956,
#   'Nicole Roberts',
#   'gmoore@example.com',
#   '13656 Valerie Stream Apt. 468',
#   'New Madison',
#   'Arizona',
#   'Bahrain',
#   '715.993.2542x2786',
#   'Likely low take Congress newspaper adult few.',
#   '1931-08-31',
#   1040,
#   '2022-02-20 07:14:57.843939',
#   '2022-02-20 07:14:57.843941',
#   '26.177.214.153'),
#  (957,
#   'James Holt',
#   'beverlymiller@example.org',
#   '5777 Peterson Glens Suite 179',
#   'New Laurenmouth',
#   'Wisconsin',
#   'Nigeria',
#   '(410)365-9758',
#   'Physical education last first realize street show.',
#   '1921-11-21',
#   1888,
#   '2022-02-20 07:14:57.844723',
#   '2022-02-20 07:14:57.844724',
#   '152.239.76.164'),
#  (958,
#   'Chelsea Kennedy',
#   'russelllewis@example.org',
#   '2322 Chan Spurs',
#   'South Alexanderville',
#   'New Hampshire',
#   'Yemen',
#   '054.922.4502x6488',
#   'Over attorney reveal range author phone drug hold.',
#   '1957-03-28',
#   2490,
#   '2022-02-20 07:14:57.845496',
#   '2022-02-20 07:14:57.845497',
#   '48.140.69.190'),
#  (959,
#   'Marc Diaz',
#   'qcarter@example.net',
#   '468 Perkins Valley Apt. 210',
#   'Dannyville',
#   'Connecticut',
#   'Tunisia',
#   '(707)960-8430',
#   'Couple purpose quickly energy argue move. Boy push whole order single say '
#   'most.',
#   '1932-04-17',
#   1576,
#   '2022-02-20 07:14:57.846223',
#   '2022-02-20 07:14:57.846225',
#   '130.167.123.4'),
#  (960,
#   'Thomas Smith',
#   'umorton@example.net',
#   '320 May Harbors',
#   'Darrentown',
#   'Maryland',
#   'Jersey',
#   '(595)373-2722',
#   'Happen board medical article court probably.',
#   '1995-02-24',
#   1698,
#   '2022-02-20 07:14:57.846924',
#   '2022-02-20 07:14:57.846925',
#   '17.112.135.156'),
#  (961,
#   'Chris Smith',
#   'diana98@example.net',
#   '224 Sandra Skyway',
#   'Johnsonborough',
#   'Pennsylvania',
#   'Zambia',
#   '3006799599',
#   'Most eight expert note. Congress summer happen foreign.',
#   '1986-03-02',
#   2279,
#   '2022-02-20 07:14:57.847604',
#   '2022-02-20 07:14:57.847605',
#   '39.20.148.197'),
#  (962,
#   'Angela Scott',
#   'sierra40@example.net',
#   '7601 Nicole Ranch',
#   'West Ashley',
#   'Wisconsin',
#   'Liberia',
#   '579-355-4533x6172',
#   'Evening able role describe officer perform. Blue leg ahead rich space.',
#   '1975-05-18',
#   1779,
#   '2022-02-20 07:14:57.848279',
#   '2022-02-20 07:14:57.848280',
#   '58.73.63.156'),
#  (963,
#   'Robert Ramirez',
#   'christinanelson@example.com',
#   '92846 Cole Crossing Apt. 262',
#   'New Alexander',
#   'Alaska',
#   "Cote d'Ivoire",
#   '+1-431-316-0184',
#   'Continue suffer occur once. Wait seat care stock.',
#   '1972-12-10',
#   2258,
#   '2022-02-20 07:14:57.849038',
#   '2022-02-20 07:14:57.849039',
#   '90.72.101.252'),
#  (964,
#   'Emily Watkins',
#   'gibsonrachael@example.net',
#   '570 Morgan Court',
#   'South Christineburgh',
#   'Minnesota',
#   'Eritrea',
#   '+1-791-223-5782x75894',
#   'Woman throughout movement management authority suddenly community yard.',
#   '1949-03-03',
#   1851,
#   '2022-02-20 07:14:57.849810',
#   '2022-02-20 07:14:57.849811',
#   '37.242.225.252'),
#  (965,
#   'Diana Montoya',
#   'michael56@example.com',
#   '39447 Kennedy Glen',
#   'Traciemouth',
#   'Illinois',
#   'Malaysia',
#   '(658)521-8057x91949',
#   'Glass close small produce staff news. North its difficult.',
#   '1967-08-21',
#   2478,
#   '2022-02-20 07:14:57.850502',
#   '2022-02-20 07:14:57.850503',
#   '1.153.153.68'),
#  (966,
#   'Jeanne Tanner',
#   'anna75@example.org',
#   '7516 Peter Throughway Apt. 215',
#   'South Lauren',
#   'North Dakota',
#   'Congo',
#   '(376)491-8526x4253',
#   'Project approach exist rock source. Week against although add reality '
#   'small.',
#   '1921-08-03',
#   2462,
#   '2022-02-20 07:14:57.851175',
#   '2022-02-20 07:14:57.851176',
#   '66.10.166.174'),
#  (967,
#   'Shane Erickson',
#   'cynthiaobrien@example.com',
#   '464 Jennifer Avenue Suite 133',
#   'Lake Bethborough',
#   'Alabama',
#   'Western Sahara',
#   '001-585-881-2720x977',
#   'For condition according usually. Without fine song race term win manager.',
#   '1968-07-27',
#   1150,
#   '2022-02-20 07:14:57.851943',
#   '2022-02-20 07:14:57.851944',
#   '124.219.78.104'),
#  (968,
#   'Joshua Bell',
#   'louis72@example.com',
#   '42110 Murphy Avenue Apt. 833',
#   'South Charleschester',
#   'Nevada',
#   'Argentina',
#   '(052)704-1508x86957',
#   'Easy song program few reduce best chance. Law find be throw culture box '
#   'deep.',
#   '1959-09-03',
#   1240,
#   '2022-02-20 07:14:57.852655',
#   '2022-02-20 07:14:57.852656',
#   '27.73.26.28'),
#  (969,
#   'Courtney Young',
#   'monicalarsen@example.com',
#   '39416 Cain Isle Apt. 981',
#   'Raymondstad',
#   'Wisconsin',
#   'Argentina',
#   '605-477-3900x4442',
#   'More wear discuss money card.',
#   '1924-09-08',
#   1676,
#   '2022-02-20 07:14:57.853466',
#   '2022-02-20 07:14:57.853467',
#   '90.225.130.80'),
#  (970,
#   'Zachary Hampton',
#   'scott79@example.net',
#   '53960 Blake Mountain',
#   'Lake Elijahshire',
#   'Rhode Island',
#   'Western Sahara',
#   '686.211.0439',
#   'Military hospital though theory. Class become why role. Quite special '
#   'music.',
#   '1954-12-03',
#   1461,
#   '2022-02-20 07:14:57.854134',
#   '2022-02-20 07:14:57.854135',
#   '203.205.45.139'),
#  (971,
#   'Nicholas Williams',
#   'brittany98@example.net',
#   '7836 Xavier Crest Apt. 325',
#   'New Gabriel',
#   'New Jersey',
#   'Syrian Arab Republic',
#   '001-845-677-2523x7139',
#   'Event behavior west campaign approach race.',
#   '2001-12-15',
#   1831,
#   '2022-02-20 07:14:57.854809',
#   '2022-02-20 07:14:57.854811',
#   '102.184.83.189'),
#  (972,
#   'Jamie Strong',
#   'robertmcmahon@example.net',
#   '2461 Jeffrey Tunnel Suite 765',
#   'Alexanderberg',
#   'Iowa',
#   'Belarus',
#   '3657987621',
#   'Worker stock student next piece toward off.',
#   '2002-09-25',
#   1433,
#   '2022-02-20 07:14:57.855543',
#   '2022-02-20 07:14:57.855544',
#   '59.154.89.196'),
#  (973,
#   'Leon Mills',
#   'kmiller@example.com',
#   '76247 Jennifer Key Suite 425',
#   'North Sonya',
#   'New Hampshire',
#   'Guadeloupe',
#   '+1-282-916-4182',
#   'Religious allow design dog hope out. Matter try talk become likely.',
#   '1950-03-27',
#   1194,
#   '2022-02-20 07:14:57.856244',
#   '2022-02-20 07:14:57.856246',
#   '38.54.186.90'),
#  (974,
#   'Barbara Wolf',
#   'tbrown@example.net',
#   '76234 Melissa Coves Apt. 060',
#   'Gibsonhaven',
#   'Minnesota',
#   'Oman',
#   '303.416.3597x2860',
#   'Simple meet your sit six. Wall act what become thing red individual '
#   'instead.',
#   '1975-06-21',
#   1046,
#   '2022-02-20 07:14:57.856966',
#   '2022-02-20 07:14:57.856967',
#   '141.89.66.52'),
#  (975,
#   'Martin Washington',
#   'chamberskimberly@example.net',
#   '13951 Davis Motorway',
#   'North Keithtown',
#   'Oregon',
#   'Netherlands Antilles',
#   '828-426-0614x06057',
#   'Story imagine marriage see various about. Amount great cup important.',
#   '1911-09-16',
#   1729,
#   '2022-02-20 07:14:57.857733',
#   '2022-02-20 07:14:57.857734',
#   '96.235.144.45'),
#  (976,
#   'Shelby Bates',
#   'christopherrivera@example.com',
#   '618 Marcia Keys Suite 503',
#   'East Kaylaburgh',
#   'Arizona',
#   'South Georgia and the South Sandwich Islands',
#   '001-245-267-1699',
#   'After owner point. Go above series skin generation plan.',
#   '1971-03-14',
#   2281,
#   '2022-02-20 07:14:57.858524',
#   '2022-02-20 07:14:57.858525',
#   '142.10.242.10'),
#  (977,
#   'Alex Bell',
#   'johnmanning@example.net',
#   '5793 Greene Square',
#   'Scottstad',
#   'Vermont',
#   'Yemen',
#   '427.568.0987',
#   'Check unit keep throw. Executive again item organization figure late.',
#   '1933-12-04',
#   1762,
#   '2022-02-20 07:14:57.859475',
#   '2022-02-20 07:14:57.859477',
#   '26.104.152.49'),
#  (978,
#   'Yolanda Walker',
#   'bgardner@example.com',
#   '00195 Sherry Creek',
#   'Saundersfurt',
#   'South Dakota',
#   'Georgia',
#   '182.137.5616x620',
#   'Star so yes read research factor. Sing yet act far degree.',
#   '2006-08-01',
#   1311,
#   '2022-02-20 07:14:57.860189',
#   '2022-02-20 07:14:57.860191',
#   '71.78.238.104'),
#  (979,
#   'Emily Reeves',
#   'phillipsjacob@example.net',
#   '038 Johnny Terrace',
#   'Hardyburgh',
#   'Massachusetts',
#   'Estonia',
#   '099.265.5869',
#   'Protect challenge size threat range project defense. Though her concern.',
#   '1967-09-23',
#   1435,
#   '2022-02-20 07:14:57.860948',
#   '2022-02-20 07:14:57.860950',
#   '214.105.167.144'),
#  (980,
#   'Jennifer Johnson',
#   'ustanley@example.org',
#   '79037 Melissa Drives Suite 007',
#   'Carlsonhaven',
#   'Arizona',
#   'Gabon',
#   '4072419082',
#   'Activity increase pay condition. Wrong draw red although name mention make.',
#   '1909-01-21',
#   1606,
#   '2022-02-20 07:14:57.861673',
#   '2022-02-20 07:14:57.861674',
#   '136.205.181.52'),
#  (981,
#   'George Peterson',
#   'rboyd@example.com',
#   '446 Kimberly Port Suite 919',
#   'Stephanieside',
#   'Nebraska',
#   'Latvia',
#   '760.905.0120x6801',
#   'Usually throughout research project range like. Program similar '
#   'development.',
#   '1974-07-11',
#   1845,
#   '2022-02-20 07:14:57.862451',
#   '2022-02-20 07:14:57.862452',
#   '142.167.29.26'),
#  (982,
#   'Zachary White',
#   'cjohnson@example.net',
#   '462 Angela Burg',
#   'Coffeyville',
#   'Utah',
#   'Ukraine',
#   '001-636-186-6748x69007',
#   'Commercial television learn doctor per.',
#   '1927-05-22',
#   2051,
#   '2022-02-20 07:14:57.863379',
#   '2022-02-20 07:14:57.863381',
#   '134.138.158.213'),
#  (983,
#   'Adrian Harris',
#   'eallison@example.org',
#   '5980 Vega Freeway Suite 280',
#   'South Rhonda',
#   'Alaska',
#   'Saudi Arabia',
#   '566.332.6971x5499',
#   'While rise difficult try person when. Ahead safe shoulder morning growth.',
#   '1940-12-23',
#   2205,
#   '2022-02-20 07:14:57.864170',
#   '2022-02-20 07:14:57.864171',
#   '15.178.76.168'),
#  (984,
#   'Erica Johnson',
#   'mary94@example.org',
#   '783 Karl Avenue Apt. 921',
#   'Katelynfurt',
#   'Alabama',
#   'Zimbabwe',
#   '703.199.9076x922',
#   'Issue during nation no start company. Expert public gas teach oil.',
#   '1940-01-31',
#   1182,
#   '2022-02-20 07:14:57.864915',
#   '2022-02-20 07:14:57.864917',
#   '23.234.71.232'),
#  (985,
#   'Jeffrey Willis',
#   'jeffrey23@example.org',
#   '715 Stewart View Suite 976',
#   'Nathanfurt',
#   'Virginia',
#   'Iraq',
#   '+1-586-896-7889x97063',
#   'Standard attack watch result grow catch opportunity career.',
#   '1928-11-01',
#   1910,
#   '2022-02-20 07:14:57.865669',
#   '2022-02-20 07:14:57.865670',
#   '171.150.2.234'),
#  (986,
#   'Cameron Bean',
#   'alyssagross@example.net',
#   '28413 Shannon Mall Apt. 713',
#   'South Aaron',
#   'Rhode Island',
#   'Bhutan',
#   '+1-691-021-8288x92074',
#   'Drive process bed fly thus six. Effort Congress can include specific own.',
#   '1923-01-19',
#   1134,
#   '2022-02-20 07:14:57.866572',
#   '2022-02-20 07:14:57.866574',
#   '147.178.192.123'),
#  (987,
#   'John Mccoy',
#   'xjenkins@example.net',
#   '447 Dylan Park Suite 750',
#   'New Patrickview',
#   'Utah',
#   'Ethiopia',
#   '737.019.0652x09771',
#   'Court know air next safe. Fine modern himself director audience.',
#   '1915-06-08',
#   1769,
#   '2022-02-20 07:14:57.867315',
#   '2022-02-20 07:14:57.867317',
#   '119.11.196.118'),
#  (988,
#   'Sheila Dodson',
#   'normanterrence@example.org',
#   '8573 Taylor Coves Apt. 942',
#   'Teresabury',
#   'Tennessee',
#   'United States Virgin Islands',
#   '813.925.8012',
#   'Tough arrive movie help who. Feel TV meet party fine.',
#   '1992-05-10',
#   1771,
#   '2022-02-20 07:14:57.868091',
#   '2022-02-20 07:14:57.868093',
#   '205.253.56.185'),
#  (989,
#   'Bethany Roberts',
#   'csantiago@example.net',
#   '02054 Kathryn Village Apt. 615',
#   'East Leslie',
#   'Mississippi',
#   'Niger',
#   '(933)249-2610',
#   'Way reason center push anyone couple.',
#   '1982-06-27',
#   1236,
#   '2022-02-20 07:14:57.868790',
#   '2022-02-20 07:14:57.868792',
#   '41.62.177.201'),
#  (990,
#   'Gregory Boyd',
#   'nbrown@example.net',
#   '800 Peter Course Apt. 045',
#   'Hunterberg',
#   'Oregon',
#   'Cyprus',
#   '+1-493-429-2167x6716',
#   'Benefit front stuff sing surface great. Much magazine cut sit forget.',
#   '1963-12-19',
#   1257,
#   '2022-02-20 07:14:57.869521',
#   '2022-02-20 07:14:57.869522',
#   '191.211.17.183'),
#  (991,
#   'Christine Miller',
#   'xlawrence@example.com',
#   '62858 Cody Gardens Apt. 717',
#   'Blakeberg',
#   'Wisconsin',
#   'Saint Helena',
#   '001-273-896-8606x162',
#   'Visit whose security fact find what. Watch wish all then far.',
#   '1932-10-18',
#   1387,
#   '2022-02-20 07:14:57.870238',
#   '2022-02-20 07:14:57.870240',
#   '117.137.72.171'),
#  (992,
#   'Jennifer Richmond',
#   'noblelaura@example.com',
#   '78080 Cline Lakes Suite 121',
#   'Ballardborough',
#   'Montana',
#   'Puerto Rico',
#   '716.118.6834x13110',
#   'Play economic beyond machine. Full note ago less.',
#   '1987-11-02',
#   1593,
#   '2022-02-20 07:14:57.871040',
#   '2022-02-20 07:14:57.871041',
#   '4.73.161.212'),
#  (993,
#   'Ronald Herrera',
#   'kirsten51@example.com',
#   '0801 Luis Estate',
#   'Susanville',
#   'Minnesota',
#   'Solomon Islands',
#   '(170)538-3752',
#   'Reflect safe store nearly group stage.',
#   '1961-05-17',
#   2161,
#   '2022-02-20 07:14:57.871678',
#   '2022-02-20 07:14:57.871679',
#   '215.174.118.59'),
#  (994,
#   'Michael Juarez',
#   'brandon13@example.net',
#   '1815 Robinson Mall',
#   'Keithstad',
#   'Georgia',
#   'Algeria',
#   '053.170.9756',
#   'Shake claim mother recognize idea. Despite simple out action growth.',
#   '1920-07-19',
#   1544,
#   '2022-02-20 07:14:57.872369',
#   '2022-02-20 07:14:57.872370',
#   '203.106.225.26'),
#  (995,
#   'Dustin Thomas',
#   'james31@example.org',
#   '02982 Andrew Overpass Suite 264',
#   'Aaronborough',
#   'Minnesota',
#   'Uruguay',
#   '(498)087-0323',
#   'Letter interest example she modern father soldier. Very indeed able focus.',
#   '1986-05-09',
#   1765,
#   '2022-02-20 07:14:57.873036',
#   '2022-02-20 07:14:57.873037',
#   '129.121.96.29'),
#  (996,
#   'James Long',
#   'jwilson@example.org',
#   '68439 Miller Bypass',
#   'Robinsonhaven',
#   'Michigan',
#   'Macedonia',
#   '5940852640',
#   'Thus travel down consumer only discover though structure.',
#   '1971-01-21',
#   1052,
#   '2022-02-20 07:14:57.873749',
#   '2022-02-20 07:14:57.873751',
#   '142.254.73.124'),
#  (997,
#   'Angela Long',
#   'matthew79@example.org',
#   '961 Christine Fields',
#   'New Michelleland',
#   'Minnesota',
#   'Mali',
#   '(150)867-4908',
#   'Tough cover tough always now chance green. Record blue act amount.',
#   '1980-05-23',
#   1745,
#   '2022-02-20 07:14:57.874408',
#   '2022-02-20 07:14:57.874409',
#   '28.63.59.97'),
#  (998,
#   'Angela West',
#   'fwalters@example.org',
#   '780 Lucas Plains Apt. 794',
#   'Lake Reginald',
#   'Louisiana',
#   'French Polynesia',
#   '(842)183-6981',
#   'Fear college hope indeed. Feel require hair figure inside avoid watch '
#   'market.',
#   '1925-10-18',
#   1378,
#   '2022-02-20 07:14:57.875121',
#   '2022-02-20 07:14:57.875122',
#   '30.126.39.17'),
#  (999,
#   'Monica Melton',
#   'beth29@example.com',
#   '5022 Sean Cliffs',
#   'Garyport',
#   'Maryland',
#   'Reunion',
#   '001-157-185-2147x983',
#   'War table during we fall him family. Audience accept improve concern '
#   'strong.',
#   '1911-10-04',
#   1866,
#   '2022-02-20 07:14:57.875790',
#   '2022-02-20 07:14:57.875791',
#   '42.170.15.56'),
#  (1000,
#   'Brandi Smith',
#   'kberry@example.com',
#   '0828 Peter Freeway Suite 748',
#   'East Sergiomouth',
#   'Illinois',
#   'Cyprus',
#   '001-653-958-4682x93627',
#   'Almost bill pick note time rate. Price political performance year.',
#   '1907-12-02',
#   1479,
#   '2022-02-20 07:14:57.876492',
#   '2022-02-20 07:14:57.876493',
#   '221.105.202.226')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
from pprint import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

Statement = "SELECT * FROM people WHERE heatmap > 1500 LIMIT 20"

myCursor.execute(Statement)
results = myCursor.fetchall()
pprint(results)
# Out:
# [(1,
#   'Dr. Seth Grant',
#   'gguerrero@example.org',
#   '34586 Carl Field Apt. 200',
#   'Leachland',
#   'Oregon',
#   'Bouvet Island (Bouvetoya)',
#   '897-964-6033x413',
#   'West region less hard return window.',
#   '1956-11-30',
#   2347,
#   '2022-02-20 07:14:56.991547',
#   '2022-02-20 07:14:56.991549',
#   '77.115.57.112'),
#  (4,
#   'Robert Bautista',
#   'hamiltonstacy@example.net',
#   '673 Kim Mills Apt. 384',
#   'Riverastad',
#   'Maryland',
#   'Bulgaria',
#   '001-448-699-1785x7082',
#   'Big professor for. Skill agree imagine new water yet never.',
#   '1911-06-03',
#   1939,
#   '2022-02-20 07:14:57.119875',
#   '2022-02-20 07:14:57.119876',
#   '185.179.174.75'),
#  (5,
#   'Christy Arellano',
#   'hcastaneda@example.com',
#   '71777 Durham Grove',
#   'North Michael',
#   'Florida',
#   'Indonesia',
#   '+1-449-035-0611x44484',
#   'Southern focus realize recent organization. Building natural maybe mouth.',
#   '1914-06-08',
#   2178,
#   '2022-02-20 07:14:57.120644',
#   '2022-02-20 07:14:57.120645',
#   '73.87.145.240'),
#  (7,
#   'Sherry Gonzalez',
#   'tgreene@example.org',
#   '945 Floyd Circles Apt. 812',
#   'Joshuamouth',
#   'North Dakota',
#   'Macedonia',
#   '001-265-084-1255x5205',
#   'Without people authority world. Miss machine order think.',
#   '1969-10-23',
#   1567,
#   '2022-02-20 07:14:57.122129',
#   '2022-02-20 07:14:57.122130',
#   '165.59.111.251'),
#  (8,
#   'Joseph Barnett',
#   'yaguilar@example.com',
#   '1054 Lucas Dale Suite 980',
#   'Sarahborough',
#   'Texas',
#   'Kazakhstan',
#   '9644281667',
#   'Sort executive more interest type between charge.',
#   '2021-08-09',
#   2036,
#   '2022-02-20 07:14:57.122855',
#   '2022-02-20 07:14:57.122856',
#   '119.252.42.188'),
#  (9,
#   'April Harris',
#   'keithmiller@example.com',
#   '1864 David Tunnel Suite 239',
#   'Molinaborough',
#   'New Hampshire',
#   'Indonesia',
#   '001-685-061-4217',
#   'Agreement get system population result new. Address campaign yes them.',
#   '1967-12-18',
#   1944,
#   '2022-02-20 07:14:57.123633',
#   '2022-02-20 07:14:57.123634',
#   '5.233.212.40'),
#  (12,
#   'Alexandra Gomez',
#   'lauriemarshall@example.org',
#   '9648 Karen Rue Apt. 163',
#   'Lake Michael',
#   'Kentucky',
#   'Qatar',
#   '766.026.7681x28551',
#   'Worry pay majority allow girl. System now show once front up window.',
#   '1925-01-29',
#   2353,
#   '2022-02-20 07:14:57.125834',
#   '2022-02-20 07:14:57.125836',
#   '121.7.124.91'),
#  (17,
#   'Rodney Wood',
#   'pcarroll@example.net',
#   '685 Kara Track',
#   'Stephanieview',
#   'Colorado',
#   'Turkmenistan',
#   '001-061-713-5464',
#   'Production hard west establish art sound memory. Stage whatever down '
#   'maintain.',
#   '1958-01-13',
#   1683,
#   '2022-02-20 07:14:57.129466',
#   '2022-02-20 07:14:57.129468',
#   '11.139.90.177'),
#  (20,
#   'Amber Clark',
#   'hayleynelson@example.net',
#   '45561 Crawford Mall',
#   'Johnsonside',
#   'Louisiana',
#   'Paraguay',
#   '934-238-2559x2085',
#   'Happen perhaps nor glass positive oil notice. Plan because wall hospital '
#   'into.',
#   '1960-09-19',
#   1887,
#   '2022-02-20 07:14:57.131784',
#   '2022-02-20 07:14:57.131786',
#   '89.242.148.249'),
#  (21,
#   'David Elliott',
#   'michael82@example.org',
#   '377 Mullen Common Suite 358',
#   'Carlamouth',
#   'Wisconsin',
#   'United States Virgin Islands',
#   '(745)745-0003',
#   'Five best population full effort enjoy catch open.',
#   '1975-08-24',
#   1616,
#   '2022-02-20 07:14:57.132474',
#   '2022-02-20 07:14:57.132475',
#   '20.226.85.24'),
#  (22,
#   'Devin Estes DDS',
#   'christopher13@example.com',
#   '67468 Sharon Cape',
#   'Lake Johnport',
#   'Idaho',
#   'Saint Lucia',
#   '001-369-209-2479x4517',
#   'Pass despite such stand.',
#   '1970-08-14',
#   2316,
#   '2022-02-20 07:14:57.133122',
#   '2022-02-20 07:14:57.133123',
#   '163.235.102.171'),
#  (23,
#   'Lisa Flores',
#   'angela06@example.net',
#   '7043 West Ways Apt. 060',
#   'Buckleymouth',
#   'Connecticut',
#   'Mali',
#   '881.404.1070x9497',
#   'When talk whom far little. Question already various include.',
#   '1923-05-27',
#   2308,
#   '2022-02-20 07:14:57.133944',
#   '2022-02-20 07:14:57.133945',
#   '180.72.137.90'),
#  (24,
#   'Karina Simmons',
#   'matthewspears@example.net',
#   '79569 Felicia Cliffs',
#   'Palmerhaven',
#   'Minnesota',
#   'Togo',
#   '(777)865-2009x71157',
#   'Benefit recent she nature. Amount heavy people mother painting bring.',
#   '1949-04-15',
#   1580,
#   '2022-02-20 07:14:57.134752',
#   '2022-02-20 07:14:57.134754',
#   '159.204.231.230'),
#  (25,
#   'Henry Gray',
#   'williamknight@example.net',
#   '461 James Lake Suite 994',
#   'Ruizchester',
#   'Montana',
#   'Ecuador',
#   '354-668-6288x082',
#   'Wind result business. Book father structure around support final.',
#   '1950-09-05',
#   1811,
#   '2022-02-20 07:14:57.135557',
#   '2022-02-20 07:14:57.135558',
#   '147.109.122.133'),
#  (26,
#   'John Colon',
#   'popeashley@example.org',
#   '749 Nathan Locks',
#   'Kennethborough',
#   'Delaware',
#   'Luxembourg',
#   '+1-076-302-8337x918',
#   'Might it subject democratic tend nor. Happy final let activity dog town.',
#   '1994-04-08',
#   1784,
#   '2022-02-20 07:14:57.136307',
#   '2022-02-20 07:14:57.136308',
#   '189.71.92.186'),
#  (29,
#   'Misty Garcia',
#   'woodsamy@example.net',
#   '260 Brown Trail Suite 697',
#   'Jonesberg',
#   'Iowa',
#   'Saint Kitts and Nevis',
#   '001-608-176-2838x70522',
#   'Reach seven community officer want economic guess.',
#   '1934-08-08',
#   2282,
#   '2022-02-20 07:14:57.138574',
#   '2022-02-20 07:14:57.138575',
#   '142.168.122.199'),
#  (30,
#   'David Leach',
#   'robertlewis@example.org',
#   '24526 Hines Pines Apt. 722',
#   'Jarvisstad',
#   'Montana',
#   'Sierra Leone',
#   '2290783957',
#   'Down base arrive. Care war short talk when economic.',
#   '1993-12-07',
#   1589,
#   '2022-02-20 07:14:57.139366',
#   '2022-02-20 07:14:57.139368',
#   '74.71.22.232'),
#  (32,
#   'Anthony Mcclure',
#   'parrishcindy@example.com',
#   '340 Jared Ways Apt. 625',
#   'West Keith',
#   'Arizona',
#   'Barbados',
#   '588-288-7444x10979',
#   'Own last spend. North help network sometimes senior friend represent teach.',
#   '1912-03-21',
#   1616,
#   '2022-02-20 07:14:57.140828',
#   '2022-02-20 07:14:57.140830',
#   '84.94.25.246'),
#  (33,
#   'Jason Salazar',
#   'jeremy43@example.net',
#   '872 Schultz Roads Apt. 234',
#   'Port Stephenberg',
#   'Montana',
#   'Belarus',
#   '775-668-5633x130',
#   'Two team conference establish cultural compare increase.',
#   '2012-04-05',
#   2060,
#   '2022-02-20 07:14:57.141522',
#   '2022-02-20 07:14:57.141523',
#   '160.107.129.59'),
#  (34,
#   'Michael Clay',
#   'christian46@example.net',
#   '1257 Paul Terrace',
#   'West Sarahmouth',
#   'Maine',
#   'Nicaragua',
#   '769.413.1201',
#   'Generation recent of. Production oil out skill state old give.',
#   '1971-03-19',
#   2077,
#   '2022-02-20 07:14:57.142196',
#   '2022-02-20 07:14:57.142197',
#   '138.96.208.216')]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
